# %% [markdown]
# # 01 — Ingestão ANAC → Bronze
#
# Carrega VRA e bases SoR (microdados, municípios, origens/destinos, tarifas, operações) para Delta Bronze no Databricks Free.
#
# Código de verdade no git. Catálogo sugerido: `vooai.bronze`.
#
# Protótipo existente: `ingestao-anac.ipynb` — alinhar URLs reais da ANAC neste notebook.

# %%
# Databricks Free: ajustar catálogo/schema disponível
CATALOG = "vooai"
SCHEMA = "bronze"
print(f"Target: {CATALOG}.{SCHEMA}")
