# %% [markdown]
# # 02 — Ingestão de cotações → Bronze
#
# Lê a saída de `collectors/` (JSON/CSV) e grava Delta Bronze sem alteração funcional.
# Schema: ver `docs/dicionario-de-dados.md`.

# %%
print("Ingerir cotações do collector para vooai.bronze.quotes_raw")
