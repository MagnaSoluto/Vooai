# %% [markdown]
# # 05 — Regressão (MLflow)
#
# Target: preço futuro ou variação percentual. Validação temporal (sem shuffle). Baseline linear + RF / boosting. Métricas MAE, RMSE, R² complementar.

# %%
print("Registrar runs no MLflow do Databricks Free")
