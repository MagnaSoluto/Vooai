# %% [markdown]
# # 03 — Bronze → Silver
#
# Limpeza, padronização IATA, deduplicação, nulos, feature engineering (lead_days, dia da semana, mês).

# %%
print("vooai.silver.quotes / vooai.silver.vra_ops")
