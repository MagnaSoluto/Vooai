# %% [markdown]
# # 07 — Gold e recomendação
#
# Combina previsão + regra ±5% (COMPRAR / AGUARDAR / MONITORAR) + KPIs ANAC. Tabelas para dashboard e export `data/gold/`.

# %%
THRESHOLD = 0.05
print(f"Regra inicial: COMPRAR se >= +{THRESHOLD:.0%}; AGUARDAR se <= -{THRESHOLD:.0%}")
