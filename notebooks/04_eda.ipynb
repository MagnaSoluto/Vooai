# %% [markdown]
# # 04 — EDA
#
# Descritiva, outliers, correlação, sazonalidade, preço por antecedência, distribuição de atrasos/cancelamentos.

# %%
print("EDA — documentar achados em docs/ e no README ao fechar a semana 3")
